# %%
import numpy as np
import time

from Functions.Metropolis import *
from Functions.errorcalc import *
from Functions.Minimalization import *
from Functions.PlotFigures import *
import Systems.HarmonicOscillator  as Oscillator
import Systems.Hatom as Hydrogen
import Systems.Helium as Helium

def minimalEnergyFinder(alpha_guess, N_walkers, N_tries, System, plots, subplots, plotsave):
    """ For a given system finds the optimal ground state energy.

    Parameters
    ----------
    alpha_guess:            int; first value of alpha
    N_walkers:              Number of random walkers placed
    N_tries:                Number of steps for the walkers to try
    System:                 current system. Can choose between: oscillator, Hydrogen or Helium
    plots:                  True or False to plot the results


    """
    start_time = time.time()
    
    alpha, count, E_loc , E_a= minimalAlphaFinder(alpha_guess, N_tries, N_walkers, System)

    E_var = np.zeros(len(alpha))
    E_error = np.zeros(len(alpha))
    var_error = np.zeros(len(alpha))

    for i in range(len(alpha)):
       E_error[i], E_var[i], var_error[i] = bootstrapError(E_loc[i,:,0], 100)

    alpha_min = alpha[-1]
    E_min = E_a[-1]

    print()
    print("The energy was found to be minimal with \N{greek small letter alpha} = {}".format(alpha_min))
    print("The corresponding Energy is E = {} +/- {}".format(E_min, E_error[-1]))
    print("With variance var = {} +/- {} ".format(E_var[-1], var_error[-1]))

    # plots
    if plots == True and subplots == False:
        plotMinumumAlpha(alpha, count)
        
        plotEnergy(alpha, E_a, E_error)
        
        plotVariance(alpha, E_var, var_error)
        
        
    elif plots == False and subplots == True:
        subplotEnergyVarianceAlpha(alpha, E_a, E_error, E_var, var_error, count, plotsave)

    elapsed_time = time.time() - start_time
    print(f"time taken for simulation : {elapsed_time} s")

# %%
print("This cell will give the optimal Ground state energy of the Harmonic oscillator system:")
print()

# System parameters
System = Oscillator
N_tries = 10000
N_walkers = 50
alpha_guess = 1.2

# plots
plots = False
subplots = True
plotsave = True

minimalEnergyFinder(alpha_guess, N_walkers, N_tries, System, plots, subplots, plotsave)
# Out:
# This cell will give the optimal Ground state energy of the Harmonic oscillator system:
#
# alpha: 0.9996535732030036, iteration: 1
# alpha: 0.8129147524574346, iteration: 2
# alpha: 0.6589003153008826, iteration: 3
# alpha: 0.5589758225809368, iteration: 4
# alpha: 0.5105893810068406, iteration: 5
# alpha: 0.5002939485513396, iteration: 6
# alpha: 0.4999902706999822, iteration: 7
#
# The energy was found to be minimal with α = 0.4999902706999822
# The corresponding Energy is E = 0.4999948774166969 +/- 4.0630410424309715e-06
# With variance var = 1.782172840139723e-07 +/- 6.387078020300247e-09
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-839f9120d366> in <module>
#      13 plotsave = True
#      14
# ---> 15 minimalEnergyFinder(alpha_guess, N_walkers, N_tries, System, plots, subplots, plotsave)
#
# <ipython-input-1-ed4939e54b33> in minimalEnergyFinder(alpha_guess, N_walkers, N_tries, System, plots, subplots, plotsave)
#      52
#      53     elif plots == False and subplots == True:
# ---> 54         subplotEnergyVariance(alpha, E_a, E_error, E_var, var_error, plotsave)
#      55
#      56     elapsed_time = time.time() - start_time
#
# TypeError: subplotEnergyVariance() takes 5 positional arguments but 6 were given

# %%
print("This cell will give the optimal Ground state energy of the Hydrogen atom system:")
print()

# System parameters
System = Hydrogen
N_tries = 10000
N_walkers = 50
alpha_guess = 1.2
plots = True
subplots = False

minimalEnergyFinder(alpha_guess, N_walkers, N_tries, System, plots, subplots)
# Out:
# This cell will give the optimal Ground state energy of the Hydrogen atom system:
#
# alpha: 1.1073610419975894, iteration: 1
# alpha: 1.0571593485408006, iteration: 2
# alpha: 1.0301587622556374, iteration: 3
# alpha: 1.0161971658465174, iteration: 4
# alpha: 1.0085917478224484, iteration: 5
# alpha: 1.0046851946275708, iteration: 6
# alpha: 1.0025265128986776, iteration: 7
# alpha: 1.0013345868901624, iteration: 8
# alpha: 1.0007126880096684, iteration: 9
#
# The energy was found to be minimal with α = 1.0007126880096684
# The corresponding Energy is E = -0.5000312068044247 +/- 1.2186523379044248e-05
# With variance var = 1.4213106447448991e-06 +/- 1.995750667079274e-07
# time taken for simulation : 10.247700929641724 s

# %%
print("This cell will give the optimal Ground state energy of the Helium atom system:")
print()

# System parameters
System = Helium
N_tries = 10000
N_walkers = 50
alpha_guess = 0.25
plots = True
subplots = False

minimalEnergyFinder(alpha_guess, N_walkers, N_tries, System, plots, subplots)
# Out:
# This cell will give the optimal Ground state energy of the Helium atom system:
#
# alpha: 0.22125159229636604, iteration: 1
# alpha: 0.1957297728844245, iteration: 2
# alpha: 0.17604020283571353, iteration: 3
# alpha: 0.164512477166042, iteration: 4
# alpha: 0.15512208305912467, iteration: 5
# alpha: 0.15104805132456156, iteration: 6
# alpha: 0.14811227196533538, iteration: 7
# alpha: 0.148063443434165, iteration: 8
#
# The energy was found to be minimal with α = 0.148063443434165
# The corresponding Energy is E = -2.8765977797562052 +/- 0.003331363272220832
# With variance var = 0.1119068822306683 +/- 0.0015837573609225595
# time taken for simulation : 18.814669370651245 s
