# %%
import numpy as np
import time

from Functions.Metropolis import *
from Functions.errorcalc import *
from Functions.PlotFigures import *
import Systems.HarmonicOscillator  as Oscillator
import Systems.Hatom as Hydrogen
import Systems.Helium as Helium




def VMC(N_walkers, N_tries, System, plots):
    start_time = time.time()
    
    alpha = System.alpha_broad
    D = System.dimension

    E_a = np.zeros(len(alpha))
    E_var = np.zeros(len(alpha))
    E_error = np.zeros(len(alpha))
    var_error = np.zeros(len(alpha))

    for i in range(len(alpha)):
        f = lambda R: System.trialWaveFunction(alpha[i],  R)

        rn, accept_rate = metropolisAlgorithm(f, N_tries, N_walkers, D)
        E = System.E_loc(alpha[i], rn)
        E_a[i] = np.mean(E)
        E_error[i], E_var[i], var_error[i] = bootstrapError(E[:,0], 100)

    print("E(\N{greek small letter alpha}))")
    print(E_a)
    print("var(E(\N{greek small letter alpha})))")
    print(E_var)
    print(f"Acceptance rate : {accept_rate}")

    if plots == True:
        subplotEnergyVariance(alpha, E_a, E_error, E_var, var_error)
    
    elapsed_time = time.time() - start_time
    print(f"time taken for simulation : {elapsed_time} s")

# %%
print("This cell gives the energy and variance of the harmonic oscilator in 1D:")
print()

# Simulation parameters
System = Oscillator
N_tries = 10000
N_walkers = 50
plots = True

VMC(N_walkers, N_tries, System, plots)
# Out:
# This cell gives the energy and variance of the harmonic oscilator in 1D:
#
# E(α))
# [0.50923729 0.502654   0.5        0.50254393 0.51002872]
# var(E(α)))
# [0.02322623 0.00566173 0.         0.00448599 0.015982  ]
# Acceptance rate : 0.855726
# time taken for simulation : 2.7515676021575928 s

# %%
print("This cell gives the energy and variance of the Hydrogen atom in 3D:")
print()

# Simulation parameters
System = Hydrogen
N_tries = 10000
N_walkers = 50
plots = True

VMC(N_walkers, N_tries, System, plots)
# Out:
# This cell gives the energy and variance of the Hydrogen atom in 3D:
#
# E(α))
# [-0.479206   -0.49182081 -0.5        -0.49821566 -0.48635621]
# var(E(α)))
# [0.02180669 0.00625467 0.         0.00984153 0.04372696]
# Acceptance rate : 0.7303346666666667
# time taken for simulation : 4.660080432891846 s

# %%
print("This cell gives the energy and variance of the Hydrogen atom in 3D:")
print()

# Simulation parameters
System = Helium
N_tries = 10000
N_walkers = 50
plots = True

VMC(N_walkers, N_tries, System, plots)
# Out:
# This cell gives the energy and variance of the Hydrogen atom in 3D:
#
# E(α))
# [-2.87252224 -2.87474652 -2.88010824 -2.87739024 -2.87786694 -2.8759145
#  -2.87333884 -2.8750066 ]
# var(E(α)))
# [0.17708708 0.15194352 0.13684488 0.1223051  0.11241099 0.1009
#  0.09533607 0.09158874]
# Acceptance rate : 0.4777956666666667
# time taken for simulation : 15.073633193969727 s
